# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn import svm
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
import pickle

# %%
data_path = r"C:\Users\SARITHA\Desktop\disease outbreak\datasets\parkinsons.csv"  
data = pd.read_csv(data_path)

# %%
print("First 5 rows of the dataset:")
data.head()
# Out:
# First 5 rows of the dataset:
#              name   MDVPFo  MDVPFhi  MDVPFlo  MDVPJitter  MDVPJitterAbsolute  \
# 0  phon_R01_S01_1  119.992  157.302   74.997     0.00784             0.00007
# 1  phon_R01_S01_2  122.400  148.650  113.819     0.00968             0.00008
# 2  phon_R01_S01_3  116.682  131.111  111.555     0.01050             0.00009
# 3  phon_R01_S01_4  116.676  137.871  111.366     0.00997             0.00009
# 4  phon_R01_S01_5  116.014  141.781  110.655     0.01284             0.00011
#
#    MDVPRAP  MDVPPPQ  JitterDDP  MDVPShimmer  ...  ShimmerDDA      NHR     HNR  \
# 0  0.00370  0.00554    0.01109      0.04374  ...     0.06545  0.02211  21.033
# 1  0.00465  0.00696    0.01394      0.06134  ...     0.09403  0.01929  19.085
# 2  0.00544  0.00781    0.01633      0.05233  ...     0.08270  0.01309  20.651
# 3  0.00502  0.00698    0.01505      0.05492  ...     0.08771  0.01353  20.644
# 4  0.00655  0.00908    0.01966      0.06425  ...     0.10470  0.01767  19.649
#
#    status      RPDE       DFA   spread1   spread2        D2       PPE
# 0       1  0.414783  0.815285 -4.813031  0.266482  2.301442  0.284654
# 1       1  0.458359  0.819521 -4.075192  0.335590  2.486855  0.368674
# 2       1  0.429895  0.825288 -4.443179  0.311173  2.342259  0.332634
# 3       1  0.434969  0.819235 -4.117501  0.334147  2.405554  0.368975
# 4       1  0.417356  0.823484 -3.747787  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %%
# Checking for missing values
print("\nMissing values in the dataset:")
print(data.isnull().sum())
# Out:
# Missing values in the dataset:
# name                  0
# MDVPFo                0
# MDVPFhi               0
# MDVPFlo               0
# MDVPJitter            0
# MDVPJitterAbsolute    0
# MDVPRAP               0
# MDVPPPQ               0
# JitterDDP             0
# MDVPShimmer           0
# MDVPShimmerdecibal    0
# ShimmerAPQ3           0
# ShimmerAPQ5           0
# MDVPAPQ               0
# ShimmerDDA            0
# NHR                   0
# HNR                   0
# status                0
# RPDE                  0
# DFA                   0
# spread1               0
# spread2               0
# D2                    0
# PPE                   0
# dtype: int64

# %%
# Define features (X) and target (Y)
X = data.drop(columns=['name', 'status'], axis=1)  # Dropping 'name' and 'status' columns
Y = data['status']

# %%
# Standardize the feature data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.utils import resample

# Assuming X and Y are your original data and target variables
X_resampled, Y_resampled = resample(X, Y, random_state=42)
# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X_resampled, Y_resampled, test_size=0.2, stratify=Y_resampled, random_state=2)

# %%
# Display the shapes of the splits
print("\nShapes of the data splits:")
print(f"X: {X.shape}")
print(f"X_train: {X_train.shape}")
print(f"X_test: {X_test.shape}")
# Out:
# Shapes of the data splits:
# X: (195, 22)
# X_train: (156, 22)
# X_test: (39, 22)

# %%
model = svm.SVC(random_state=2)
model.fit(X_train, Y_train)
# Out:
# SVC(random_state=2)

# %%
# Calculate training accuracy
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification #example dataset

# Create example dataset
X, Y = make_classification(n_samples=1000, n_features=20, random_state=42)

# Split the data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Train the model
best_model = RandomForestClassifier(random_state=42)
best_model.fit(X_train, Y_train)

# Calculate training accuracy
train_accuracy = best_model.score(X_train, Y_train)
print(f"\nTraining Accuracy: {train_accuracy * 100:.2f}%")
# Out:
# Training Accuracy: 100.00%

# %%
# Make predictions on the test set
Y_pred = best_model.predict(X_test)

# Calculate test accuracy
test_accuracy = accuracy_score(Y_test, Y_pred)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Test Accuracy: 90.00%

# %%
# Classification report
print("\nClassification Report:")
print(classification_report(Y_test, Y_pred))

# Confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(Y_test, Y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90        93
#            1       0.95      0.86      0.90       107
#
#     accuracy                           0.90       200
#    macro avg       0.90      0.90      0.90       200
# weighted avg       0.90      0.90      0.90       200
#
#
# Confusion Matrix:
# [[88  5]
#  [15 92]]

# %%
# Build a predictive system
sample_data = np.array([X_test[0]])  
sample_prediction = best_model.predict(sample_data)
print("\nSample Prediction:", "Parkinson's" if sample_prediction[0] == 1 else "No Parkinson's")
# Out:
# Sample Prediction: Parkinson's

# %%
# Save the model to a .sav file
model_filename = "parkinsons_model.sav"
with open(model_filename, 'wb') as model_file:
    pickle.dump(best_model, model_file)

print(f"\nModel saved to {model_filename}")
# Out:
# Model saved to parkinsons_model.sav

# %%
# Save the scaler for future use in prediction
scaler_filename = "scaler_parkinsons.sav"
with open(scaler_filename, 'wb') as scaler_file:
    pickle.dump(scaler, scaler_file)

print(f"Scaler saved to {scaler_filename}")

# Print column names
print("\nColumns in the dataset:")
data.columns.tolist()
# Out:
# Scaler saved to scaler_parkinsons.sav
#
# Columns in the dataset:
# ['name',
#  'MDVPFo',
#  'MDVPFhi',
#  'MDVPFlo',
#  'MDVPJitter',
#  'MDVPJitterAbsolute',
#  'MDVPRAP',
#  'MDVPPPQ',
#  'JitterDDP',
#  'MDVPShimmer',
#  'MDVPShimmerdecibal',
#  'ShimmerAPQ3',
#  'ShimmerAPQ5',
#  'MDVPAPQ',
#  'ShimmerDDA',
#  'NHR',
#  'HNR',
#  'status',
#  'RPDE',
#  'DFA',
#  'spread1',
#  'spread2',
#  'D2',
#  'PPE']
